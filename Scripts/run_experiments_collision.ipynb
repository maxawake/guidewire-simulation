# %%
from utils import *
import numpy as np
import multiprocessing as mp
import os

UNITY_APP_PATH = "/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64"
SAVE_PATH = "/home/max/Temp/Praktikum/collision"
PARAMETER_PATH = "/home/max/Github/guidewire-simulation/Scripts/parameters-collision.json"

REPEAT = 3 # Repeat each experiment REPEAT times
MP_CPUS = 8 # Number of CPUs to use for multiprocessing
NICENESS = 1 # Niceness of the Unity process

# %% [markdown]
# # Test experiment script

# %%
parameter_path = "/home/max/Github/guidewire-simulation/Scripts/sample-collision.json"
log_path = "/home/max/Github/guidewire-simulation/Scripts/example-log.txt"


run_unity(UNITY_APP_PATH, parameter_path, log_path, headless=False)
# Out:
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-transversal-verlet.x86_64 -parameters /home/max/Github/guidewire-simulation/Scripts/sample-parameters.json -logFile /home/max/Github/guidewire-simulation/Scripts/example-log.txt -monitor 2
# Unity process finished with exit code: -11
# CompletedProcess(args=['/home/max/Documents/Unity/guidewire-simulation-transversal-verlet.x86_64', '-parameters', '/home/max/Github/guidewire-simulation/Scripts/sample-parameters.json', '-logFile', '/home/max/Github/guidewire-simulation/Scripts/example-log.txt', '-monitor', '2'], returncode=-11)

# %% [markdown]
# # Constraint solver steps

# %%
parameters = read_json_file(PARAMETER_PATH)

# Reference solution
parameters["constraintSolverSteps"] = 1000
experiment_folder, name = prepare_experiment(SAVE_PATH, f"constraint_solver_steps_reference")
run_expriment(UNITY_APP_PATH, experiment_folder, name, parameters)

constraint_solver_steps = np.arange(100,1100,100)#[100, 200, 300, 400, 500]

# repeat ten times to get some statistics
for i in range(REPEAT):
    experiment_folder, name = prepare_experiment(SAVE_PATH, f"constraint_solver_steps_{i}")

    def temp_fun(css):
        parametes_new = parameters.copy()
        parametes_new["constraintSolverSteps"] = int(css)
        run_expriment(UNITY_APP_PATH, experiment_folder, name+f"_{css}", parametes_new)

    with mp.Pool(MP_CPUS, initializer=set_nice, initargs=(NICENESS,)) as p:
        p.map(temp_fun, constraint_solver_steps)
# Out:
# logFilePath: /home/max/Temp/Praktikum/experiments/
# constraintSolverSteps: 500
# timeStep: 0.001
# displacement: 1.0
# guidewireLength: 300.0
# numberRodElements: 30
# totalMass: 0.01
# guidewireOffset: -130.0
# bendStiffness: 0.1
# stretchStiffness: 0.1
# sphereRadius: 5.0
# collisionMargin: 5
# collisionStiffness: 0.001
# deltaThreshold: 0.0
# damping: 0.01
# VerletIntegration: True
# SteadyState: True
# maxSimulationSteps: 500
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_reference/constraint_solver_steps_reference/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_reference/constraint_solver_steps_reference/log.txt -monitor 2
# Unity process finished with exit code: -11
# Set niceness to:  Set niceness to: 1  1Set niceness to:
#
#
# 1
#  Set niceness to:
#
# 1Set niceness to:
# 1
#  Set niceness to:
#
# 1
# Set niceness to:
#  1
#
# Set niceness to:  Running Unity with the following command:1Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:
#
#
#
#
#
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_300/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_300/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_200/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_200/log.txt -monitor 2
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_600/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_600/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_100/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_100/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_500/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_500/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_700/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_700/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_400/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_400/log.txt -monitor 2
#
#
#
#
#
#
#
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_800/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_800/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_900/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_900/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_1000/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_0/constraint_solver_steps_0_1000/log.txt -monitor 2
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Set niceness to:  1Set niceness to:
#
# Set niceness to: 1
# Set niceness to: 1
#
# 1Set niceness to:
#
#
# 1Set niceness to:
# 1
# Set niceness to:
# 1
#
# Set niceness to:
# Running Unity with the following command:Running Unity with the following command: Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:
# Running Unity with the following command:
#
# 1
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_600/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_600/log.txt -monitor 2
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_100/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_100/log.txt -monitor 2
#  /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_400/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_400/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_300/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_300/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_200/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_200/log.txt -monitor 2
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_500/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_500/log.txt -monitor 2
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_700/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_700/log.txt -monitor 2
#
#
#
#
#
#
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_800/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_800/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_900/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_900/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_1000/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_1/constraint_solver_steps_1_1000/log.txt -monitor 2
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Set niceness to: Set niceness to:   11  Set niceness to:
#
#
#
# 1 Set niceness to:
#  1
#  Set niceness to:
#
#  1
# Set niceness to:
# 1Set niceness to:
# 1
#
# Running Unity with the following command:Running Unity with the following command:Set niceness to: Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:
#
#
#
#
#
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_400/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_400/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_100/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_100/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_200/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_200/log.txt -monitor 21/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_500/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_500/log.txt -monitor 2Running Unity with the following command:/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_600/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_600/log.txt -monitor 2
#
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_300/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_300/log.txt -monitor 2
#
#
#
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_700/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_700/log.txt -monitor 2
#
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_800/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_800/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_900/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_900/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_1000/parameters.json -logFile /home/max/Temp/Praktikum/collision/constraint_solver_steps_2/constraint_solver_steps_2_1000/log.txt -monitor 2
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11

# %% [markdown]
# # Time steps

# %%
parameters = read_json_file(PARAMETER_PATH)

# Reference solution
parameters["timeStep"] = 1e-4
experiment_folder, name = prepare_experiment(SAVE_PATH, f"time_steps_reference")
run_expriment(UNITY_APP_PATH, experiment_folder, name, parameters)

timesteps = np.logspace(-4, 0, 10)

for i in range(REPEAT):
    experiment_folder, name = prepare_experiment(SAVE_PATH, f"time_steps_{i}")
    
    def temp_fun(t):
        parametes_new = parameters.copy()
        parametes_new["timeStep"] = t
        run_expriment(UNITY_APP_PATH, experiment_folder, name + f"_{t}", parametes_new)

    with mp.Pool(MP_CPUS, initializer=set_nice, initargs=(NICENESS,)) as p:
        p.map(temp_fun, timesteps)
# Out:
# logFilePath: /home/max/Temp/Praktikum/experiments/
# constraintSolverSteps: 500
# timeStep: 0.001
# displacement: 1.0
# guidewireLength: 300.0
# numberRodElements: 30
# totalMass: 0.01
# guidewireOffset: -130.0
# bendStiffness: 0.1
# stretchStiffness: 0.1
# sphereRadius: 5.0
# collisionMargin: 5
# collisionStiffness: 0.001
# deltaThreshold: 0.0
# damping: 0.01
# VerletIntegration: True
# SteadyState: True
# maxSimulationSteps: 500
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_reference/time_steps_reference/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_reference/time_steps_reference/log.txt -monitor 2
# Unity process finished with exit code: -11
# Set niceness to:  1Set niceness to:
# 1
# Set niceness to:
# 1
# Set niceness to:
# 1
# Set niceness to:   1
#
# Set niceness to:
#
#  1 Set niceness to:
#
# 1
# Set niceness to:
#  Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:1
#
#
#
#
#
#
#  /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.0001/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.0001/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.0002782559402207126/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.0002782559402207126/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.016681005372000592/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.016681005372000592/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.046415888336127774/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.046415888336127774/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.002154434690031882/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.002154434690031882/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.000774263682681127/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.000774263682681127/log.txt -monitor 2
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.005994842503189409/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.005994842503189409/log.txt -monitor 2
#
#
#
#
#
#
#
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.12915496650148828/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.12915496650148828/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.3593813663804626/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_0.3593813663804626/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_1.0/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_0/time_steps_0_1.0/log.txt -monitor 2
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Set niceness to: Set niceness to:   1Set niceness to: 1
#
# 1Set niceness to:
#
#
# 1
#
# Set niceness to:
#  1
#
# Set niceness to:  1
# Set niceness to:
#  1
#
# Set niceness to: Running Unity with the following command:Running Unity with the following command: Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:
# 1
#
#
#
#
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.005994842503189409/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.005994842503189409/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.000774263682681127/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.000774263682681127/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.046415888336127774/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.046415888336127774/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.016681005372000592/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.016681005372000592/log.txt -monitor 2 /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.0002782559402207126/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.0002782559402207126/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.0001/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.0001/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.002154434690031882/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.002154434690031882/log.txt -monitor 2
#
#
#
#
#
#
#
#
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.12915496650148828/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.12915496650148828/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.3593813663804626/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_0.3593813663804626/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_1.0/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_1/time_steps_1_1.0/log.txt -monitor 2
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Set niceness to:  1Set niceness to:
#
# Set niceness to: 1
# 1
#
#
# Set niceness to:  1Set niceness to:   1
#  Set niceness to:
#
#
#  1Set niceness to:
# 1
#
#
# Set niceness to: Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:
#
#
#
#
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.0002782559402207126/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.0002782559402207126/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.016681005372000592/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.016681005372000592/log.txt -monitor 21/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.000774263682681127/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.000774263682681127/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.0001/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.0001/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.005994842503189409/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.005994842503189409/log.txt -monitor 2
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.002154434690031882/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.002154434690031882/log.txt -monitor 2
#
#
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.046415888336127774/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.046415888336127774/log.txt -monitor 2
#
#
#
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.12915496650148828/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.12915496650148828/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.3593813663804626/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_0.3593813663804626/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_1.0/parameters.json -logFile /home/max/Temp/Praktikum/collision/time_steps_2/time_steps_2_1.0/log.txt -monitor 2
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11

# %% [markdown]
# # Numer of Rod Elements

# %%
parameters = read_json_file(PARAMETER_PATH)

# Reference solution
parameters["numberRodElements"] = 100
experiment_folder, name = prepare_experiment(SAVE_PATH, f"rod_elements_reference")
run_expriment(UNITY_APP_PATH, experiment_folder, name, parameters)

elements = [100, 50, 25, 20, 10, 5, 4, 2]
#np.arange(4,40,2, dtype="int").astype("float")

for i in range(REPEAT):
    experiment_folder, name = prepare_experiment(SAVE_PATH, f"rod_elements_{i}")

    def temp_fun(e):
        parametes_new = parameters.copy()
        parametes_new["numberRodElements"] = e
        run_expriment(UNITY_APP_PATH, experiment_folder, name + f"_{e}", parametes_new)

    with mp.Pool(MP_CPUS, initializer=set_nice, initargs=(NICENESS,)) as p:
        p.map(temp_fun, elements)
# Out:
# logFilePath: /home/max/Temp/Praktikum/experiments/
# constraintSolverSteps: 500
# timeStep: 0.001
# displacement: 1.0
# guidewireLength: 300.0
# numberRodElements: 30
# totalMass: 0.01
# guidewireOffset: -130.0
# bendStiffness: 0.1
# stretchStiffness: 0.1
# sphereRadius: 5.0
# collisionMargin: 5
# collisionStiffness: 0.001
# deltaThreshold: 0.0
# damping: 0.01
# VerletIntegration: True
# SteadyState: True
# maxSimulationSteps: 500
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_reference/rod_elements_reference/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_reference/rod_elements_reference/log.txt -monitor 2
# Unity process finished with exit code: -11
# Set niceness to:  Set niceness to: 1  1Set niceness to:
#
#
# Set niceness to: 1
#
# 1Set niceness to:
#
# 1Set niceness to:
#   1
#
#
# Set niceness to:
#  1
# Running Unity with the following command:Set niceness to: Running Unity with the following command:Running Unity with the following command:
# Running Unity with the following command:Running Unity with the following command:
# Running Unity with the following command:
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_0/rod_elements_0_100/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_0/rod_elements_0_100/log.txt -monitor 2
#
#
# 1/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_0/rod_elements_0_25/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_0/rod_elements_0_25/log.txt -monitor 2Running Unity with the following command:/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_0/rod_elements_0_50/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_0/rod_elements_0_50/log.txt -monitor 2
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_0/rod_elements_0_10/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_0/rod_elements_0_10/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_0/rod_elements_0_5/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_0/rod_elements_0_5/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_0/rod_elements_0_20/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_0/rod_elements_0_20/log.txt -monitor 2
#
#
#
#
#
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_0/rod_elements_0_4/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_0/rod_elements_0_4/log.txt -monitor 2
#
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_0/rod_elements_0_2/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_0/rod_elements_0_2/log.txt -monitor 2
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Set niceness to: Set niceness to:  1 Set niceness to: 1
# 1Set niceness to:
#
#
# 1
#
#
# Set niceness to:
#  1 Set niceness to:
#
# 1Set niceness to:
#
# 1
# Set niceness to:
#  1Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:
#
#
#
#
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_1/rod_elements_1_100/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_1/rod_elements_1_100/log.txt -monitor 2
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_1/rod_elements_1_50/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_1/rod_elements_1_50/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_1/rod_elements_1_25/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_1/rod_elements_1_25/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_1/rod_elements_1_20/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_1/rod_elements_1_20/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_1/rod_elements_1_5/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_1/rod_elements_1_5/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_1/rod_elements_1_4/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_1/rod_elements_1_4/log.txt -monitor 2
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_1/rod_elements_1_10/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_1/rod_elements_1_10/log.txt -monitor 2
#
#
#
#
#
#
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_1/rod_elements_1_2/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_1/rod_elements_1_2/log.txt -monitor 2
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Set niceness to: Set niceness to:  1 Set niceness to:  1
#
#
# Set niceness to: 1
#
# 1
# Set niceness to:   1
#  Set niceness to:
#
#
#  Set niceness to: 1
# 1
#
#
# Set niceness to: Running Unity with the following command:Running Unity with the following command: Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:
# 1
#
#
#
#
#  /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_2/rod_elements_2_100/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_2/rod_elements_2_100/log.txt -monitor 2
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_2/rod_elements_2_50/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_2/rod_elements_2_50/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_2/rod_elements_2_5/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_2/rod_elements_2_5/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_2/rod_elements_2_4/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_2/rod_elements_2_4/log.txt -monitor 2
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_2/rod_elements_2_25/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_2/rod_elements_2_25/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_2/rod_elements_2_20/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_2/rod_elements_2_20/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_2/rod_elements_2_10/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_2/rod_elements_2_10/log.txt -monitor 2
#
#
#
#
#
#
#
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/rod_elements_2/rod_elements_2_2/parameters.json -logFile /home/max/Temp/Praktikum/collision/rod_elements_2/rod_elements_2_2/log.txt -monitor 2
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11

# %% [markdown]
# # Total mass

# %%
parameters = read_json_file(PARAMETER_PATH)

# Reference solution
parameters["totalMass"] = 0.01
experiment_folder, name = prepare_experiment(SAVE_PATH, f"total_mass_reference")
run_expriment(UNITY_APP_PATH, experiment_folder, name, parameters)

masses = np.linspace(0.01,1,10)

for i in range(REPEAT):
    experiment_folder, name = prepare_experiment(SAVE_PATH, f"total_mass_{i}")
    
    def temp_fun(m):
        parametes_new = parameters.copy()
        parametes_new["totalMass"] = m
        run_expriment(UNITY_APP_PATH, experiment_folder, name + f"_{m}", parametes_new)

    with mp.Pool(MP_CPUS, initializer=set_nice, initargs=(NICENESS,)) as p:
        p.map(temp_fun, masses)
# Out:
# logFilePath: /home/max/Temp/Praktikum/experiments/
# constraintSolverSteps: 500
# timeStep: 0.001
# displacement: 1.0
# guidewireLength: 300.0
# numberRodElements: 30
# totalMass: 0.01
# guidewireOffset: -130.0
# bendStiffness: 0.1
# stretchStiffness: 0.1
# sphereRadius: 5.0
# collisionMargin: 5
# collisionStiffness: 0.001
# deltaThreshold: 0.0
# damping: 0.01
# VerletIntegration: True
# SteadyState: True
# maxSimulationSteps: 500
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_reference/total_mass_reference/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_reference/total_mass_reference/log.txt -monitor 2
# Unity process finished with exit code: -11
# Set niceness to:  Set niceness to: 1
# 1Set niceness to:
#
# 1Set niceness to:
#
#
# Set niceness to: 1
#
# 1Set niceness to:
#
# 1
# Set niceness to:
#  1
# Running Unity with the following command:Running Unity with the following command:
# Set niceness to: Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:
#
#
#
#
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.23/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.23/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.01/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.01/log.txt -monitor 2Running Unity with the following command:/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.12/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.12/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.45/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.45/log.txt -monitor 21/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.56/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.56/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.34/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.34/log.txt -monitor 2
#
#
#
#
#
#
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.67/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.67/log.txt -monitor 2
#
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.78/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.78/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.89/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_0.89/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_1.0/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_0/total_mass_0_1.0/log.txt -monitor 2
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Set niceness to: Set niceness to:  1 1Set niceness to:    1
#
# Set niceness to:
#
# 1
# Set niceness to:
#
#
# 1Set niceness to:
#
# 1Set niceness to:
#
# 1
# Set niceness to:
#  1Running Unity with the following command:Running Unity with the following command: Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:
# Running Unity with the following command:
#
#
#
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.34/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.34/log.txt -monitor 2
#
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.01/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.01/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.56/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.56/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.67/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.67/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.12/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.12/log.txt -monitor 2
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.45/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.45/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.23/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.23/log.txt -monitor 2
#
#
#
# Running Unity with the following command:
#
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.78/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.78/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.89/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_0.89/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_1.0/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_1/total_mass_1_1.0/log.txt -monitor 2
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Set niceness to:  1Set niceness to:
#
#  Set niceness to: 1 1
# Set niceness to:
#
#
#  1Set niceness to:   1
#
#  Set niceness to:
# 1
#
#
# Set niceness to:  1
#
# Set niceness to: Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command:Running Unity with the following command: Running Unity with the following command:
#
#
#
#
#
#
# 1/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.23/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.23/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.45/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.45/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.67/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.67/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.56/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.56/log.txt -monitor 2
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.01/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.01/log.txt -monitor 2/home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.12/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.12/log.txt -monitor 2
#
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.34/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.34/log.txt -monitor 2
#
#
#
#
#
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.78/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.78/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.89/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_0.89/log.txt -monitor 2
# Unity process finished with exit code: -11
# Running Unity with the following command:
# /home/max/Documents/Unity/guidewire-simulation-verlet-collision.x86_64 -parameters /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_1.0/parameters.json -logFile /home/max/Temp/Praktikum/collision/total_mass_2/total_mass_2_1.0/log.txt -monitor 2
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
# Unity process finished with exit code: -11
